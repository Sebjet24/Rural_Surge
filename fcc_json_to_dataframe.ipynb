# %%
import json

# %%
with open("Resources/fcc_json_broadband.json") as f:
    data = json.load(f)

# %%
import pandas as pd
df = pd.DataFrame(columns=["logrecno","provider_id","frn","providername","dbaname","holdingcompanyname",
                           "hoconum","hocofinal","stateabbr","blockcode","techcode","consumer","maxaddown",
                           "maxadup","business"])

# %%
for i in range(0,len(data)):
    currentItem = data[i]
    df.loc[i] = [data[i]["logrecno"],data[i]["provider_id"],data[i]["frn"],data[i]["providername"],data[i]["dbaname"],
                 data[i]["holdingcompanyname"],data[i]["hoconum"],data[i]["hocofinal"],data[i]["stateabbr"],data[i]["blockcode"],
                 data[i]["techcode"],data[i]["consumer"],data[i]["maxaddown"],data[i]["maxadup"],data[i]["business"]]

# %%
df
# Out:
#      logrecno provider_id         frn  providername     dbaname  \
# 0    10586435       70592  0004963088  ViaSat, Inc.  Viasat Inc
# 1    10586436       70592  0004963088  ViaSat, Inc.  Viasat Inc
# 2    10586437       70592  0004963088  ViaSat, Inc.  Viasat Inc
# 3    10586438       70592  0004963088  ViaSat, Inc.  Viasat Inc
# 4    10586439       70592  0004963088  ViaSat, Inc.  Viasat Inc
# ..        ...         ...         ...           ...         ...
# 995  10587430       70592  0004963088  ViaSat, Inc.  Viasat Inc
# 996  10587431       70592  0004963088  ViaSat, Inc.  Viasat Inc
# 997  10587432       70592  0004963088  ViaSat, Inc.  Viasat Inc
# 998  10587433       70592  0004963088  ViaSat, Inc.  Viasat Inc
# 999  10587434       70592  0004963088  ViaSat, Inc.  Viasat Inc
#
#     holdingcompanyname hoconum     hocofinal stateabbr        blockcode  \
# 0         ViaSat, Inc.  290111  ViaSat, Inc.        MS  280679507003073
# ...
