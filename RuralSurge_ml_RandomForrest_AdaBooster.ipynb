# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Load the data
file_path = Path('Resources/ml_data_2.csv')
df = pd.read_csv(file_path)
df.head()
# Out:
#     id_ur county_desc u_r_code  avg_has_zero  avg_has_one  avg_has_two  \
# 0  20001R       Allen        R       3074.44     1268.890      818.132
# 1  20001U       Allen        U       1496.76     1107.860      629.955
# 2  20003R    Anderson        R       2491.65      431.837      712.834
# 3  20003U    Anderson        U       1127.71      422.422      289.669
# 4  20005R    Atchison        R       1128.00      449.469      285.401
#
#    avg_has_3more
# 0        2314.53
# 1        1688.42
# 2        1406.68
# 3        1064.20
# 4        1015.12

# %% [markdown]
# ### Split the Data into Training and Testing

# %%
# Create our features
X = pd.get_dummies(df.drop(["u_r_code","county_desc"], axis=1))

# Create our target
y = df["u_r_code"]

# %%
X.describe()
# Out:
#         avg_has_zero    avg_has_one    avg_has_two  avg_has_3more  \
# count     166.000000     166.000000     166.000000     166.000000
# mean     4851.178453    3698.012777    2621.773773    6297.732220
# std     12026.892941   13088.082214   10833.982167   24647.125785
# min        78.213200      42.829900      33.342400      73.614500
# 25%      1088.627500     563.271250     361.587000     707.399500
# 50%      1737.180000    1020.563500     667.086500    1392.390000
# 75%      4290.550000    2283.677500    1547.492500    3831.347500
# max    108244.000000  119434.000000  117348.000000  242088.000000
#
#        id_ur_20001R  id_ur_20001U  id_ur_20003R  id_ur_20003U  id_ur_20005R  \
# count    166.000000    166.000000    166.000000    166.000000    166.000000
# mean       0.006024      0.006024      0.006024      0.006024      0.006024
# std        0.077615      0.077615      0.077615      0.077615      0.077615
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        id_ur_20005U  ...  id_ur_20195R  id_ur_20197R  id_ur_20199R  \
# count    166.000000  ...    166.000000    166.000000    166.000000
# mean       0.006024  ...      0.006024      0.006024      0.006024
# std        0.077615  ...      0.077615      0.077615      0.077615
# min        0.000000  ...      0.000000      0.000000      0.000000
# 25%        0.000000  ...      0.000000      0.000000      0.000000
# 50%        0.000000  ...      0.000000      0.000000      0.000000
# 75%        0.000000  ...      0.000000      0.000000      0.000000
# max        1.000000  ...      1.000000      1.000000      1.000000
#
#        id_ur_20201R  id_ur_20203R  id_ur_20205R  id_ur_20205U  id_ur_20207R  \
# count    166.000000    166.000000    166.000000    166.000000    166.000000
# mean       0.006024      0.006024      0.006024      0.006024      0.006024
# std        0.077615      0.077615      0.077615      0.077615      0.077615
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        id_ur_20209R  id_ur_20209U
# count    166.000000    166.000000
# mean       0.006024      0.006024
# std        0.077615      0.077615
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max        1.000000      1.000000
#
# [8 rows x 170 columns]

# %%
# Check the balance of our target values
#y['u_r_codes'].value_counts()
y.value_counts()
# Out:
# R    105
# U     61
# Name: u_r_code, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
random_forest = BalancedRandomForestClassifier(n_estimators = 100)
random_forest = random_forest.fit(X_train, y_train)

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
y_pred = random_forest.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.711111111111111

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[24,  3],
#        [ 7,  8]], dtype=int64)

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           R       0.77      0.89      0.53      0.83      0.69      0.49        27
#           U       0.73      0.53      0.89      0.62      0.69      0.46        15
#
# avg / total       0.76      0.76      0.66      0.75      0.69      0.48        42

# %%
# List the features sorted in descending order by feature importance
sorted(zip(random_forest.feature_importances_, X.columns), reverse=True)
# Out:
# [(0
#  (0.0011547638763820852, 'id_ur_20155U'),
#  (0.0011184913333694866, 'id_ur_20197R'),
#  (0.001082359910892108, 'id_ur_20015U'),
#  (0.0010036470252323046, 'id_ur_20031R'),
#  (0.000972913978879726, 'id_ur_20007R'),
#  (0.0009706199248563956, 'id_ur_20107R'),
#  (0.0009351229272130433, 'id_ur_20089R'),
#  (0.0009091222986128865, 'id_ur_20115R'),
#  (0.0007209540952808209, 'id_ur_20123R'),
#  (0.000659841054156732, 'id_ur_20209U'),
#  (0.0006148422905715476, 'id_ur_20173U'),
#  (0.0006131001168287475, 'id_ur_20091U'),
#  (0.0006021890438290074, 'id_ur_20133R'),
#  (0.00048591402110657314, 'id_ur_20195R'),
#  (0.0, 'id_ur_20203R'),
#  (0.0, 'id_ur_20181R'),
#  (0.0, 'id_ur_20169R'),
#  (0.0, 'id_ur_20161U'),
#  (0.0, 'id_ur_20159R'),
#  (0.0, 'id_ur_20153R'),
#  (0.0, 'id_ur_20151U'),
#  (0.0, 'id_ur_20151R'),
#  (0.0, 'id_ur_20147U'),
#  (0.0, 'id_ur_20145R'),
#  (0.0, 'id_ur_20143R'),
#  (0.0, 'id_ur_20137R'),
#  (0.0, 'id_ur_20133U'),
#  (0.0, 'id_ur_20129R'),
#  (0.0, 'id_ur_20123U'),
#  (0.0, 'id_ur_20113U'),
#  (0.0, 'id_ur_20103U'),
#  (0.0, 'id_ur_20101R'),
#  (0.0, 'id_ur_20075R'),
#  (0.0, 'id_ur_20059U'),
#  (0.0, 'id_ur_20059R'),
#  (0.0, 'id_ur_20057R'),
#  (0.0, 'id_ur_20055U'),
#  (0.0, 'id_ur_20051R'),
#  (0.0, 'id_ur_20041U'),
#  (0.0, 'id_ur_20041R'),
#  (0.0, 'id_ur_20037U'),
#  (0.0, 'id_ur_20037R'),
#  (0.0, 'id_ur_20035U'),
#  (0.0, 'id_ur_20033R'),
#  (0.0, 'id_ur_20031U'),
#  (0.0, 'id_ur_20029R'),
#  (0.0, 'id_ur_20027R'),
#  (0.0, 'id_ur_20025R'),
#  (0.0, 'id_ur_20023R'),
#  (0.0, 'id_ur_20021U'),
#  (0.0, 'id_ur_20019R'),
#  (0.0, 'id_ur_20015R'),
#  (0.0, 'id_ur_20013R'),
#  (0.0, 'id_ur_20011U'),
#  (0.0, 'id_ur_20011R'),
#  (0.0, 'id_ur_20003R')]

# %% [markdown]
# ### Easy Ensemble AdaBoost Classifier

# %%
# Train the EasyEnsembleClassifier
from imblearn.ensemble import EasyEnsembleClassifier
ensemble = EasyEnsembleClassifier(n_estimators = 100,random_state=1)
ensemble = ensemble.fit(X_train, y_train)
print(ensemble)
# Out:
# EasyEnsembleClassifier(n_estimators=100, random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = ensemble.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.7259259259259259

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[23,  4],
#        [ 6,  9]], dtype=int64)

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           R       0.79      0.85      0.60      0.82      0.71      0.52        27
#           U       0.69      0.60      0.85      0.64      0.71      0.50        15
#
# avg / total       0.76      0.76      0.69      0.76      0.71      0.51        42
