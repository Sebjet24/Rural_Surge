# %%
# Suppress any warning message
import warnings
warnings.filterwarnings('ignore')

# %%
# Initital imported libraries 
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Load the data
file_path = Path('../Resources/ml_data_4.csv')
df = pd.read_csv(file_path)
df.head()
# Out:
#     id_ur county_desc u_r_code  avg_zero   avg_one  avg_two  avg_three  \
# 0  20001R       Allen        R   3074.44  1268.890  818.132    2314.53
# 1  20001U       Allen        U   1496.76  1107.860  629.955    1688.42
# 2  20003R    Anderson        R   2491.65   431.837  712.834    1406.68
# 3  20003U    Anderson        U   1127.71   422.422  289.669    1064.20
# 4  20005R    Atchison        R   1128.00   449.469  285.401    1015.12
#
#    perc_zero  perc_one  perc_two  perc_three  avg_speed  max_speed
# 0   0.024317  0.058917  0.091379    0.032300   9.800000         25
# 1   0.032891  0.044437  0.078148    0.029157   9.800000         25
# 2   0.020240  0.116780  0.070746    0.035850   9.800000         25
# 3   0.025751  0.068746  0.100252    0.027288   9.800000         25
# 4   0.025514  0.064031  0.100840    0.028351  19.822222        100

# %% [markdown]
# ### Split the Data into Training and Testing

# %%
# Create our features
X = pd.get_dummies(df.drop(["u_r_code","county_desc"], axis=1))

# Create our target
y = df["u_r_code"]

# %%
# Show statistical summary
X.describe()
# Out:
#             avg_zero        avg_one        avg_two      avg_three   perc_zero  \
# count     166.000000     166.000000     166.000000     166.000000  166.000000
# mean     4851.178453    3698.012777    2621.773773    6297.732220    0.028673
# std     12026.892941   13088.082214   10833.982167   24647.125785    0.008596
# min        78.213200      42.829900      33.342400      73.614500    0.017451
# 25%      1088.627500     563.271250     361.587000     707.399500    0.023178
# 50%      1737.180000    1020.563500     667.086500    1392.390000    0.026057
# 75%      4290.550000    2283.677500    1547.492500    3831.347500    0.031346
# max    108244.000000  119434.000000  117348.000000  242088.000000    0.066679
#
#          perc_one    perc_two  perc_three   avg_speed    max_speed  ...  \
# count  166.000000  166.000000  166.000000  166.000000   166.000000  ...
# mean     0.055840    0.079184    0.035794   14.264592    67.921687  ...
# std      0.023135    0.014945    0.007718   20.221750   184.695622  ...
# min      0.028387    0.038595    0.023727    7.233333    25.000000  ...
# 25%      0.040101    0.072115    0.029617    9.800000    25.000000  ...
# 50%      0.047978    0.078022    0.034676    9.800000    25.000000  ...
# 75%      0.067855    0.083888    0.040907    9.800000    25.000000  ...
# max      0.144126    0.139503    0.058757  129.854545  1000.000000  ...
#
#        id_ur_20195R  id_ur_20197R  id_ur_20199R  id_ur_20201R  id_ur_20203R  \
# count    166.000000    166.000000    166.000000    166.000000    166.000000
# mean       0.006024      0.006024      0.006024      0.006024      0.006024
# std        0.077615      0.077615      0.077615      0.077615      0.077615
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        id_ur_20205R  id_ur_20205U  id_ur_20207R  id_ur_20209R  id_ur_20209U
# count    166.000000    166.000000    166.000000    166.000000    166.000000
# mean       0.006024      0.006024      0.006024      0.006024      0.006024
# std        0.077615      0.077615      0.077615      0.077615      0.077615
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
# [8 rows x 176 columns]

# %%
# Check the balance of our target values [u_r_codes]
y.value_counts()
# Out:
# R    105
# U     61
# Name: u_r_code, dtype: int64

# %%
# Import library to train, test, and split dataframe
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
random_forest = BalancedRandomForestClassifier(n_estimators = 100)
random_forest = random_forest.fit(X_train, y_train)

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
y_pred = random_forest.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.8629629629629629

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[25,  2],
#        [ 3, 12]], dtype=int64)

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           R       0.89      0.93      0.80      0.91      0.86      0.75        27
#           U       0.86      0.80      0.93      0.83      0.86      0.73        15
#
# avg / total       0.88      0.88      0.84      0.88      0.86      0.74        42

# %%
# List the features sorted in descending order by feature importance
sorted(zip(random_forest.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.12644991369241199, 'perc_three'),
#  (0.11533179636731533, 'perc_zero'),
#  (0.0943000153128988, 'perc_two'),
#  (0.08329609351824553, 'perc_one'),
#  (0.07929372483714388, 'avg_three'),
#  (0.07569289501289138, 'avg_one'),
#  (0.07097963145613335, 'avg_two'),
#  (0.0635473977210054, 'avg_zero'),
#  (0.044261079167739116, 'avg_speed'),
#  (0.037309213874359974, 'max_speed'),
#  (0.01139122214494662, 'id_ur_20085U'),
#  (0.008664483777783918, 'id_ur_20191U'),
#  (0.008497519677239983, 'id_ur_20029U'),
#  (0.007136698180852643, 'id_ur_20149U'),
#  (0.00588410434345496, 'id_ur_20175U'),
#  (0.005311870448081415, 'id_ur_20087U'),
#  (0.0048547555324159365, 'id_ur_20005U'),
#  (0.0046420360935274015, 'id_ur_20145U'),
#  (0.004588788901789859, 'id_ur_20091R'),
#  (0.004565435752985044, 'id_ur_20205U'),
#  (0.004314808106088737, 'id_ur_20073U'),
#  (0.004196819098582963, 'id_ur_20173R'),
#  (0.0039051456961252894, 'id_ur_20099U'),
#  (0.003904095690026555, 'id_ur_20117U'),
#  (0.003500371632469449, 'id_ur_20009U'),
#  (0.003470652502639033, 'id_ur_20131U'),
#  (0.003337945645453358, 'id_ur_20137U'),
#  (0.003335699925695686, 'id_ur_20209R'),
#  (0.0030938942843993667, 'id_ur_20077R'),
#  (0.0029981470516690562, 'id_ur_20001U'),
#  (0.002992661948055071, 'id_ur_20121U'),
#  (0.002788228908527309, 'id_ur_20159U'),
#  (0.002661608031122006, 'id_ur_20053U'),
#  (0.002524083496842881, 'id_ur_20003U'),
#  (0.0024814874439400172, 'id_ur_20111U'),
#  (0.0024763731625740584, 'id_ur_20163R'),
#  (0.002421843514858953, 'id_ur_20113R'),
#  (0.002332057918200719, 'id_ur_20125U'),
#  (0.0022821715219659366, 'id_ur_20043U'),
#  (0.0022664872076575294, 'id_ur_20171U'),
#  (0.0022013396898748388, 'id_ur_20057U'),
#  (0.00213649448093647, 'id_ur_20197R'),
#  (0.0021054536230214827, 'id_ur_20175R'),
#  (0.0020796778063024704, 'id_ur_20177R'),
#  (0.0020778012831446494, 'id_ur_20169U'),
#  (0.0019451572945763513, 'id_ur_20127R'),
#  (0.0018837172216319405, 'id_ur_20141R'),
#  (0.0018664865396947907, 'id_ur_20091U'),
#  (0.0018579075580323894, 'id_ur_20183R'),
#  (0.0018122638297299232, 'id_ur_20045U'),
#  (0.0017933986033820304, 'id_ur_20009R'),
#  (0.0017872887396348767, 'id_ur_20079U'),
#  (0.0017757337027398932, 'id_ur_20139U'),
#  (0.001657603359776928, 'id_ur_20155R'),
#  (0.0015160726416149786, 'id_ur_20043R'),
#  (0.0003850899717330232, 'id_ur_20067R'),
#  (0.0003334454293235105, 'id_ur_20051U'),
#  (0.0002687255307984582, 'id_ur_20131R'),
#  (0.00025856850557648756, 'id_ur_20083R'),
#  (0.0002362393810068249, 'id_ur_20085R'),
#  (0.00023615002334327747, 'id_ur_20115R'),
#  (0.00022775213309219174, 'id_ur_20167R'),
#  (0.00022031510732083964, 'id_ur_20171R'),
#  (0.0002038104026830535, 'id_ur_20055R'),
#  (0.00019991649915480325, 'id_ur_20017R'),
#  (0.0001778920438334296, 'id_ur_20109R'),
#  (0.000119497735906838, 'id_ur_20073R'),
#  (0.00010493897288579955, 'id_ur_20081R'),
#  (8.639944476151428e-05, 'id_ur_20189R'),
#  (7.944551505529096e-05, 'id_ur_20099R'),
#  (6.629139025406698e-05, 'id_ur_20069R'),
#  (6.113866781501033e-05, 'id_ur_20111R'),
#  (2.5957184780905626e-05, 'id_ur_20207R'),
#  (2.5896962636747124e-05, 'id_ur_20031R'),
#  (0.0, 'id_ur_20203R'),
#  (0.0, 'id_ur_20181R'),
#  (0.0, 'id_ur_20169R'),
#  (0.0, 'id_ur_20161U'),
#  (0.0, 'id_ur_20159R'),
#  (0.0, 'id_ur_20153R'),
#  (0.0, 'id_ur_20151U'),
#  (0.0, 'id_ur_20151R'),
#  (0.0, 'id_ur_20147U'),
#  (0.0, 'id_ur_20145R'),
#  (0.0, 'id_ur_20143R'),
#  (0.0, 'id_ur_20137R'),
#  (0.0, 'id_ur_20133U'),
#  (0.0, 'id_ur_20129R'),
#  (0.0, 'id_ur_20123U'),
#  (0.0, 'id_ur_20113U'),
#  (0.0, 'id_ur_20103U'),
#  (0.0, 'id_ur_20101R'),
#  (0.0, 'id_ur_20075R'),
#  (0.0, 'id_ur_20059U'),
#  (0.0, 'id_ur_20059R'),
#  (0.0, 'id_ur_20057R'),
#  (0.0, 'id_ur_20055U'),
#  (0.0, 'id_ur_20051R'),
#  (0.0, 'id_ur_20041U'),
#  (0.0, 'id_ur_20041R'),
#  (0.0, 'id_ur_20037U'),
#  (0.0, 'id_ur_20037R'),
#  (0.0, 'id_ur_20035U'),
#  (0.0, 'id_ur_20033R'),
#  (0.0, 'id_ur_20031U'),
#  (0.0, 'id_ur_20029R'),
#  (0.0, 'id_ur_20027R'),
#  (0.0, 'id_ur_20025R'),
#  (0.0, 'id_ur_20023R'),
#  (0.0, 'id_ur_20021U'),
#  (0.0, 'id_ur_20019R'),
#  (0.0, 'id_ur_20015R'),
#  (0.0, 'id_ur_20013R'),
#  (0.0, 'id_ur_20011U'),
#  (0.0, 'id_ur_20011R'),
#  (0.0, 'id_ur_20003R')]

# %% [markdown]
# ### Easy Ensemble AdaBoost Classifier

# %%
# Train the EasyEnsembleClassifier
from imblearn.ensemble import EasyEnsembleClassifier
ensemble = EasyEnsembleClassifier(n_estimators = 100,random_state=1)
ensemble = ensemble.fit(X_train, y_train)
print(ensemble)
# Out:
# EasyEnsembleClassifier(n_estimators=100, random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = ensemble.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.825925925925926

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[23,  4],
#        [ 3, 12]], dtype=int64)

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           R       0.88      0.85      0.80      0.87      0.83      0.69        27
#           U       0.75      0.80      0.85      0.77      0.83      0.68        15
#
# avg / total       0.84      0.83      0.82      0.83      0.83      0.68        42
