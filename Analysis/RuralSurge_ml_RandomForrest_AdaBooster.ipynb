# %%
# Suppress any warning message
import warnings
warnings.filterwarnings('ignore')

# %%
# Initital imported libraries 
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Load the data
file_path = Path('../Resources/ml_data_4.csv')
df = pd.read_csv(file_path)
df.head()
# Out:
#     id_ur county_desc u_r_code  avg_zero   avg_one  avg_two  avg_three  \
# 0  20001R       Allen        R   3074.44  1268.890  818.132    2314.53
# 1  20001U       Allen        U   1496.76  1107.860  629.955    1688.42
# 2  20003R    Anderson        R   2491.65   431.837  712.834    1406.68
# 3  20003U    Anderson        U   1127.71   422.422  289.669    1064.20
# 4  20005R    Atchison        R   1128.00   449.469  285.401    1015.12
#
#    perc_zero  perc_one  perc_two  perc_three  avg_speed  max_speed
# 0   0.024317  0.058917  0.091379    0.032300   9.800000         25
# 1   0.032891  0.044437  0.078148    0.029157   9.800000         25
# 2   0.020240  0.116780  0.070746    0.035850   9.800000         25
# 3   0.025751  0.068746  0.100252    0.027288   9.800000         25
# 4   0.025514  0.064031  0.100840    0.028351  19.822222        100

# %% [markdown]
# ### Split the Data into Training and Testing

# %%
# Create our features
X = pd.get_dummies(df.drop(["u_r_code","county_desc"], axis=1))

# Create our target
y = df["u_r_code"]

# %%
# Show statistical summary
X.describe()
# Out:
#             avg_zero        avg_one        avg_two      avg_three   perc_zero  \
# count     166.000000     166.000000     166.000000     166.000000  166.000000
# mean     4851.178453    3698.012777    2621.773773    6297.732220    0.028673
# std     12026.892941   13088.082214   10833.982167   24647.125785    0.008596
# min        78.213200      42.829900      33.342400      73.614500    0.017451
# 25%      1088.627500     563.271250     361.587000     707.399500    0.023178
# 50%      1737.180000    1020.563500     667.086500    1392.390000    0.026057
# 75%      4290.550000    2283.677500    1547.492500    3831.347500    0.031346
# max    108244.000000  119434.000000  117348.000000  242088.000000    0.066679
#
#          perc_one    perc_two  perc_three   avg_speed    max_speed  ...  \
# count  166.000000  166.000000  166.000000  166.000000   166.000000  ...
# mean     0.055840    0.079184    0.035794   14.264592    67.921687  ...
# std      0.023135    0.014945    0.007718   20.221750   184.695622  ...
# min      0.028387    0.038595    0.023727    7.233333    25.000000  ...
# 25%      0.040101    0.072115    0.029617    9.800000    25.000000  ...
# 50%      0.047978    0.078022    0.034676    9.800000    25.000000  ...
# 75%      0.067855    0.083888    0.040907    9.800000    25.000000  ...
# max      0.144126    0.139503    0.058757  129.854545  1000.000000  ...
#
#        id_ur_20195R  id_ur_20197R  id_ur_20199R  id_ur_20201R  id_ur_20203R  \
# count    166.000000    166.000000    166.000000    166.000000    166.000000
# mean       0.006024      0.006024      0.006024      0.006024      0.006024
# std        0.077615      0.077615      0.077615      0.077615      0.077615
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        id_ur_20205R  id_ur_20205U  id_ur_20207R  id_ur_20209R  id_ur_20209U
# count    166.000000    166.000000    166.000000    166.000000    166.000000
# mean       0.006024      0.006024      0.006024      0.006024      0.006024
# std        0.077615      0.077615      0.077615      0.077615      0.077615
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
# [8 rows x 176 columns]

# %%
# Check the balance of our target values [u_r_codes]
y.value_counts()
# Out:
# R    105
# U     61
# Name: u_r_code, dtype: int64

# %%
# Import library to train, test, and split dataframe
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
random_forest = BalancedRandomForestClassifier(n_estimators = 100)
random_forest = random_forest.fit(X_train, y_train)

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
y_pred = random_forest.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.8444444444444444

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[24,  3],
#        [ 3, 12]], dtype=int64)

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           R       0.89      0.89      0.80      0.89      0.84      0.72        27
#           U       0.80      0.80      0.89      0.80      0.84      0.70        15
#
# avg / total       0.86      0.86      0.83      0.86      0.84      0.71        42

# %%
# List the features sorted in descending order by feature importance
sorted(zip(random_forest.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.15460822073045744, 'perc_three'),
#  (0.12298748511755238, 'perc_zero'),
#  (0.0837598656840172, 'perc_one'),
#  (0.07886774815195238, 'perc_two'),
#  (0.07862296546882606, 'avg_three'),
#  (0.07807137684181495, 'avg_zero'),
#  (0.07400186291558324, 'avg_two'),
#  (0.07023921191342886, 'avg_one'),
#  (0.040356594483081196, 'avg_speed'),
#  (0.0260365352868419, 'max_speed'),
#  (0.010279858517893615, 'id_ur_20191U'),
#  (0.008559636683546527, 'id_ur_20099U'),
#  (0.006455705204475016, 'id_ur_20029U'),
#  (0.0061961879616872365, 'id_ur_20085U'),
#  (0.0058371099285479625, 'id_ur_20175U'),
#  (0.005683355865462679, 'id_ur_20145U'),
#  (0.005150876959540274, 'id_ur_20117U'),
#  (0.0049012311825778875, 'id_ur_20043U'),
#  (0.004659950578646682, 'id_ur_20087U'),
#  (0.004626110431382754, 'id_ur_20209R'),
#  (0.004543363892485902, 'id_ur_20001U'),
#  (0.004260278255545843, 'id_ur_20061U'),
#  (0.003718363397006602, 'id_ur_20177R'),
#  (0.0037085365863836887, 'id_ur_20173R'),
#  (0.003379459861656484, 'id_ur_20091R'),
#  (0.0033519499732028255, 'id_ur_20197R'),
#  (0.002861555727707132, 'id_ur_20005R'),
#  (0.0027364258647859917, 'id_ur_20071R'),
#  (0.0026079853811684347, 'id_ur_20005U'),
#  (0.002521272911755934, 'id_ur_20067U'),
#  (0.0024769567415280414, 'id_ur_20003U'),
#  (0.0023964511560264083, 'id_ur_20095U'),
#  (0.002386122686179342, 'id_ur_20149U'),
#  (0.002267179460053484, 'id_ur_20051U'),
#  (0.0022049292556730053, 'id_ur_20205U'),
#  (0.00215011333879085, 'id_ur_20161R'),
#  (0.0021375800114284355, 'id_ur_20131U'),
#  (0.0021296362249428593, 'id_ur_20013U'),
#  (0.002071477426666603, 'id_ur_20121U'),
#  (0.002047860238324944, 'id_ur_20171U'),
#  (0.0019659735482861636, 'id_ur_20009U'),
#  (0.0018565357093772374, 'id_ur_20185R'),
#  (0.0017982551127367487, 'id_ur_20021R'),
#  (0.0017668278534540153, 'id_ur_20077R'),
#  (0.001766418342862333, 'id_ur_20149R'),
#  (0.0017652073525937489, 'id_ur_20053U'),
#  (0.001754705880461718, 'id_ur_20155R'),
#  (0.0017110501025746907, 'id_ur_20159U'),
#  (0.001702156303224854, 'id_ur_20177U'),
#  (0.0016997545533716225, 'id_ur_20189U'),
#  (0.0016905519692725448, 'id_ur_20009R'),
#  (0.0016414228662424222, 'id_ur_20181U'),
#  (0.0016152958488885112, 'id_ur_20065R'),
#  (0.0015771145280357697, 'id_ur_20111U'),
#  (0.0014998946563806446, 'id_ur_20163R'),
#  (0.0014992637227986413, 'id_ur_20093R'),
#  (0.0013036746923122137, 'id_ur_20073U'),
#  (0.0012819108033784166, 'id_ur_20127R'),
#  (0.0012249903365636663, 'id_ur_20125U'),
#  (0.0011910444257503144, 'id_ur_20157R'),
#  (0.0011250876752004137, 'id_ur_20089R'),
#  (0.001116098246637504, 'id_ur_20007R'),
#  (0.001077445372428882, 'id_ur_20091U'),
#  (0.0010511086997077746, 'id_ur_20057U'),
#  (0.0010216473300366181, 'id_ur_20167R'),
#  (0.0010058828925367514, 'id_ur_20099R'),
#  (0.0010019500543288124, 'id_ur_20043R'),
#  (0.0009728136118418402, 'id_ur_20171R'),
#  (0.0008978761595976486, 'id_ur_20135R'),
#  (0.0008453569066783355, 'id_ur_20015U'),
#  (0.0008390035253492742, 'id_ur_20039R'),
#  (0.0008378704303979184, 'id_ur_20201R'),
#  (0.0008377463595777149, 'id_ur_20165R'),
#  (0.0008317198977263681, 'id_ur_20207R'),
#  (0.000827594557243756, 'id_ur_20031R'),
#  (0.00079734345440186, 'id_ur_20027U'),
#  (0.0007902960567932796, 'id_ur_20125R'),
#  (0.0007734314800551397, 'id_ur_20131R'),
#  (0.0007703061340327379, 'id_ur_20067R'),
#  (0.0007696402160908356, 'id_ur_20053R'),
#  (0.0007642262931318417, 'id_ur_20121R'),
#  (0.0007560492189994635, 'id_ur_20081R'),
#  (0.0007538146009656154, 'id_ur_20085R'),
#  (0.0007494499184196731, 'id_ur_20139R'),
#  (0.0007211461583865609, 'id_ur_20095R'),
#  (0.0007199099980255443, 'id_ur_20199R'),
#  (0.0007113197815043917, 'id_ur_20105R'),
#  (0.0007045772630538434, 'id_ur_20183R'),
#  (0.0006757160105033703, 'id_ur_20193R'),
#  (0.0006665258892394024, 'id_ur_20109R'),
#  (0.0006645142155252122, 'id_ur_20123R'),
#  (0.0006467866521498379, 'id_ur_20061R'),
#  (0.0006447580655937368, 'id_ur_20017R'),
#  (0.0006150475681725682, 'id_ur_20137U'),
#  (0.0005971080815911774, 'id_ur_20173U'),
#  (0.000596869182779796, 'id_ur_20103R'),
#  (0.0005964061231333433, 'id_ur_20117R'),
#  (0.0005961598533086672, 'id_ur_20167U'),
#  (0.0005516288518206549, 'id_ur_20115U'),
#  (0.0005507343574106734, 'id_ur_20087R'),
#  (0.000545855647723827, 'id_ur_20175R'),
#  (0.000532965661239936, 'id_ur_20111R'),
#  (0.000527433767578903, 'id_ur_20205R'),
#  (0.00048616055612604205, 'id_ur_20055R'),
#  (0.0004576630012317929, 'id_ur_20119R'),
#  (0.00044851587949329896, 'id_ur_20209U'),
#  (0.0004454993836251378, 'id_ur_20049R'),
#  (0.00044301651873767235, 'id_ur_20063R'),
#  (0.00044030208895734046, 'id_ur_20045R'),
#  (0.00043472873697605164, 'id_ur_20139U'),
#  (0.0004301449674162347, 'id_ur_20079U'),
#  (0.00042316875653082575, 'id_ur_20191R'),
#  (0.00040583284388040323, 'id_ur_20107R'),
#  (0.0003966042229599246, 'id_ur_20045U'),
#  (0.00038850288686676524, 'id_ur_20073R'),
#  (0.00036985457410989236, 'id_ur_20195R'),
#  (0.00033594656887854437, 'id_ur_20001R'),
#  (0.00032822530720889767, 'id_ur_20113R'),
#  (0.0003122589256971005, 'id_ur_20047R'),
#  (0.00027930940393681075, 'id_ur_20193U'),
#  (0.0002766149615445998, 'id_ur_20179R'),
#  (0.0002748973972164334, 'id_ur_20169U'),
#  (0.0002127659574468072, 'id_ur_20079R'),
#  (0.00019109873306831978, 'id_ur_20187R'),
#  (0.00018119616099242456, 'id_ur_20097R'),
#  (0.0001677700755902196, 'id_ur_20133R'),
#  (0.00012269334476684701, 'id_ur_20035R'),
#  (0.0001117704371434923, 'id_ur_20083R'),
#  (0.00010547250286127551, 'id_ur_20155U'),
#  (8.987233718813265e-05, 'id_ur_20147R'),
#  (7.788041231023705e-05, 'id_ur_20141R'),
#  (4.272575894518636e-05, 'id_ur_20069R'),
#  (3.7868243501535407e-05, 'id_ur_20189R'),
#  (3.097992667482229e-05, 'id_ur_20115R'),
#  (0.0, 'id_ur_20203R'),
#  (0.0, 'id_ur_20181R'),
#  (0.0, 'id_ur_20169R'),
#  (0.0, 'id_ur_20161U'),
#  (0.0, 'id_ur_20159R'),
#  (0.0, 'id_ur_20153R'),
#  (0.0, 'id_ur_20151U'),
#  (0.0, 'id_ur_20151R'),
#  (0.0, 'id_ur_20147U'),
#  (0.0, 'id_ur_20145R'),
#  (0.0, 'id_ur_20143R'),
#  (0.0, 'id_ur_20137R'),
#  (0.0, 'id_ur_20133U'),
#  (0.0, 'id_ur_20129R'),
#  (0.0, 'id_ur_20123U'),
#  (0.0, 'id_ur_20113U'),
#  (0.0, 'id_ur_20103U'),
#  (0.0, 'id_ur_20101R'),
#  (0.0, 'id_ur_20075R'),
#  (0.0, 'id_ur_20059U'),
#  (0.0, 'id_ur_20059R'),
#  (0.0, 'id_ur_20057R'),
#  (0.0, 'id_ur_20055U'),
#  (0.0, 'id_ur_20051R'),
#  (0.0, 'id_ur_20041U'),
#  (0.0, 'id_ur_20041R'),
#  (0.0, 'id_ur_20037U'),
#  (0.0, 'id_ur_20037R'),
#  (0.0, 'id_ur_20035U'),
#  (0.0, 'id_ur_20033R'),
#  (0.0, 'id_ur_20031U'),
#  (0.0, 'id_ur_20029R'),
#  (0.0, 'id_ur_20027R'),
#  (0.0, 'id_ur_20025R'),
#  (0.0, 'id_ur_20023R'),
#  (0.0, 'id_ur_20021U'),
#  (0.0, 'id_ur_20019R'),
#  (0.0, 'id_ur_20015R'),
#  (0.0, 'id_ur_20013R'),
#  (0.0, 'id_ur_20011U'),
#  (0.0, 'id_ur_20011R'),
#  (0.0, 'id_ur_20003R')]

# %% [markdown]
# ### Easy Ensemble AdaBoost Classifier

# %%
# Train the EasyEnsembleClassifier
from imblearn.ensemble import EasyEnsembleClassifier
ensemble = EasyEnsembleClassifier(n_estimators = 100,random_state=1)
ensemble = ensemble.fit(X_train, y_train)
print(ensemble)
# Out:
# EasyEnsembleClassifier(n_estimators=100, random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = ensemble.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.825925925925926

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[23,  4],
#        [ 3, 12]], dtype=int64)

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           R       0.88      0.85      0.80      0.87      0.83      0.69        27
#           U       0.75      0.80      0.85      0.77      0.83      0.68        15
#
# avg / total       0.84      0.83      0.82      0.83      0.83      0.68        42
