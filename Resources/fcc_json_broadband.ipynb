# %%
# Dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import json
import os
# %matplotlib inline

# %%
# Load JSON
filepath = os.path.join("..", "Resources", "fcc_json_broadband.json")
with open(filepath) as jsonfile:
    json_data = json.load(jsonfile)

# %%
json_data
# Out:
# [{'logrecno': '10586435',
#   'provider_id': '70592',
#   'frn': '0004963088',
#   'providername': 'ViaSat, Inc.',
#   'dbaname': 'Viasat Inc',
#   'holdingcompanyname': 'ViaSat, Inc.',
#   'hoconum': '290111',
#   'hocofinal': 'ViaSat, Inc.',
#   'stateabbr': 'MS',
#   'blockcode': '280679507003073',
#   'techcode': '60',
#   'consumer': '1',
#   'maxaddown': '100',
#   'maxadup': '3',
#   'business': '1'},
#  {'logrecno': '10586436',
#   'provider_id': '70592',
#   'frn': '0004963088',
#   'providername': 'ViaSat, Inc.',
#   'dbaname': 'Viasat Inc',
#   'holdingcompanyname': 'ViaSat, Inc.',
#   'hoconum': '290111',
#   'hocofinal': 'ViaSat, Inc.',
#   'stateabbr': 'MS',
#   'blockcode': '280679507003074',
#   'techcode': '60',
#   'consumer': '1',
#   'maxaddown': '100',
#   'maxadup': '3',
#   'business': '1'},
#  {'logrecno': '10586437',
#   'provider_id': '70592',
#   'frn': '0004963088',
#   'providername': 'ViaSat, Inc.',
#   'dbaname': 'Viasat Inc',
# ...

# %%
provider_df = pd.read_json(json_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_688/3830203960.py in <module>
# ----> 1 provider_df = pd.read_json(json_data)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
provider_df()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_688/833219291.py in <module>
# ----> 1 provider_df()
#
# TypeError: 'DataFrame' object is not callable
